# %%
import pandas as pd
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
import json
import numpy as np
pd.set_option('display.max_columns', 500)
# %matplotlib inline

df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
df.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
from sklearn import linear_model
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

# %%
#take away mean and divide by square root of variance
#standard scaler
scaler = StandardScaler()

print(scaler.fit_transform(df['sales']))
StandardScaler(copy=True, with_mean=True, with_std=True)
Standardsales=print(StandardScaler)
#standardized sales

print(scaler.fit_transform(df['TV']))
StandardScaler(copy=True, with_mean=True, with_std=True)
StandardTV=print(StandardScaler)

print(scaler.fit_transform(df['radio']))
StandardScaler(copy=True, with_mean=True, with_std=True)
Standardradio=print(StandardScaler)

print(scaler.fit_transform(df['newspaper']))
StandardScaler(copy=True, with_mean=True, with_std=True)
Standardnewspaper=print(StandardScaler)
A = np.array([[Standardsales,StandardTV], [Standardradio, Standardnewspaper]])
#standardize all variables
y= A['Standardsales']
X = A.drop(['Standardsales'], axis=1) #StandardTV, Standardradio, Standardnewspaper #tv, newspaper, radio
#look up linear regression and follow- training data-- place into matrices?
# Out:
# 2

# %%
import math

math.sqrt(4)
# Out:
# 2.0

# %%
import pandas as pd
import pylab as plt
import seaborn
from sklearn.linear_model import LinearRegression
import numpy.random as nprnd
import random
import json
pd.set_option('display.max_columns', 500)
# %matplotlib inline
df = pd.read_csv('http://www-bcf.usc.edu/~gareth/ISL/Advertising.csv', index_col=0)
y=df['sales']
X = df.drop(['sales'], axis=1) #tv, newspaper, radio
size = float(len(X))
X_train = X[0:int(size*0.8)]
X_test = X[int(size*0.2):]
y_train = y[0:int(size*0.8)]
y_test = y[int(size*0.2):]

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

regr = LinearRegression(normalize=True)
regr.fit(X_train, y_train)
y_pred = regr.predict(X_test)
#coefficients
print('Coefficients: \n', regr.coef_)
#mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, y_pred))
#variance
print('Variance score: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients:
#  [ 0.0472521   0.179922   -0.00094408]
# Mean squared error: 2.75
# Variance score: 0.90

# %%
import numpy as np
import pandas as pd
import sys
import matplotlib.pyplot as plt
import statsmodels.api as sm
from pandas.plotting import scatter_matrix 
scatter_matrix(df,figsize=(10,10))
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split

y = df['sales']
X = df.drop(['sales'], axis=1) 

# We Choose 80% for training, 20% for testing. This should really be done randomly.

# Method 1:
size = float(len(X))
X_train = X[0:int(size*0.8)]
X_test = X[int(size*0.8):]

# Split the targets into training/testing sets
y_train = y[0:int(size*0.8)]
y_test = y[int(size*0.8):]



# Create linear regression object
regr = LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(X_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('R^2 Score: %.2f' % regr.score(X_test, y_test))
# Out:
# Coefficients:
#  [ 0.0472521   0.179922   -0.00094408]
# Residual sum of squares: 2.79
# R^2 Score: 0.90

# %%
plt.scatter(y,regr.predict(X))
plt.plot(y_test,y_test)

# %%
#nonlinear and nonparametric model
y = csv['sales']
X=csv.drop(['sales'], axis=1) 

from sklearn.tree import DecisionTreeRegressor

# We Choose 80% for training, 20% for testing. This should really be done randomly.
size = float(len(X))
X_train = X[0:int(size*0.8)]
X_test = X[int(size*0.8):]

# Split the targets into training/testing sets
y_train = y[0:int(size*0.8)]
y_test = y[int(size*0.8):]

# Create linear regression object
regr = DecisionTreeRegressor(max_depth=5)

# Train the model using the training sets
regr.fit(X_train, y_train)


# The mean square error
print("Residual sum of squares: %.2f"
      % np.mean((regr.predict(X_test) - y_test) ** 2))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % regr.score(X_test, y_test))

# %%
for x in range(1,10):
    y=x+1
    print(y)
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 10
